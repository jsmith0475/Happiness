# %% [markdown]
# # CAUSAL ANALYSIS OF WORLD HAPPINESS DATA

# %% [markdown]
# [Kaggle World Happiness](https://www.kaggle.com/unsdsn/world-happiness)
#
# [World Happiness Report](https://worldhappiness.report)

# %% [markdown]
# ## IMPORT WORLD HAPPINESS DATA

# %%
ls
# Out:
# Analysis.R             Happiness.ipynb        Raw Data/
# Happiness Index.Rproj  Project Data/

# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np

# %%
# Read in data, which is also used in the R project
data = pd.read_csv('./Project Data/happiness_train.csv')
data.head(5)
# Out:
#             rowname  score  gdp_per_capita  social_support  \
# 0  Switzerland_2015  7.587         1.39651         1.34951
# 1      Iceland_2015  7.561         1.30232         1.40223
# 2      Denmark_2015  7.527         1.32548         1.36058
# 3       Norway_2015  7.522         1.45900         1.33095
# 4       Canada_2015  7.427         1.32629         1.32261
#
#    healthy_life_expectancy  freedom_life_choices  generosity  \
# 0                  0.94143               0.66557     0.29678
# 1                  0.94784               0.62877     0.43630
# 2                  0.87464               0.64938     0.34139
# 3                  0.88521               0.66973     0.34699
# 4                  0.90563               0.63297     0.45811
#
#    perceptions_of_corruption
# 0                    0.41978
# 1                    0.14145
# 2                    0.48357
# 3                    0.36503
# 4                    0.32957

# %%
data.describe()
# Out:
#             score  gdp_per_capita  social_support  healthy_life_expectancy  \
# count  625.000000      625.000000      625.000000               625.000000
# mean     5.369778        0.916880        1.046323                 0.584162
# std      1.131287        0.407416        0.329032                 0.242117
# min      2.693000        0.000000        0.000000                 0.000000
# 25%      4.497000        0.605000        0.848290                 0.404000
# 50%      5.303000        0.982409        1.081418                 0.632106
# 75%      6.173000        1.233748        1.284025                 0.773610
# max      7.632000        1.870766        1.644000                 1.030000
#
#        freedom_life_choices  generosity  perceptions_of_corruption
# count            625.000000  625.000000                 625.000000
# mean               0.415917    0.200668                   0.155517
# std                0.154977    0.126407                   0.124996
# ...

# %%
# Drop sensitive or unused features
drop_col = ['rowname']
data = data.drop(columns=drop_col)
data.head(5)
# Out:
#    score  gdp_per_capita  social_support  healthy_life_expectancy  \
# 0  7.587         1.39651         1.34951                  0.94143
# 1  7.561         1.30232         1.40223                  0.94784
# 2  7.527         1.32548         1.36058                  0.87464
# 3  7.522         1.45900         1.33095                  0.88521
# 4  7.427         1.32629         1.32261                  0.90563
#
#    freedom_life_choices  generosity  perceptions_of_corruption
# 0               0.66557     0.29678                    0.41978
# 1               0.62877     0.43630                    0.14145
# 2               0.64938     0.34139                    0.48357
# 3               0.66973     0.34699                    0.36503
# 4               0.63297     0.45811                    0.32957

# %% [markdown]
# ## CHANGE NON-NUMERIC TO NUMERIC

# %% [markdown]
# (none to change... code is provided as reference)

# %%
import numpy as np

# %%
struct_data = data.copy()

# %%
non_numeric_columns = list(struct_data.select_dtypes(exclude=[np.number]).columns)
print(non_numeric_columns)
# Out:
# []

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
for col in non_numeric_columns:
    struct_data[col] = le.fit_transform(struct_data[col])

struct_data.head(5)
# Out:
#    score  gdp_per_capita  social_support  healthy_life_expectancy  \
# 0  7.587         1.39651         1.34951                  0.94143
# 1  7.561         1.30232         1.40223                  0.94784
# 2  7.527         1.32548         1.36058                  0.87464
# 3  7.522         1.45900         1.33095                  0.88521
# 4  7.427         1.32629         1.32261                  0.90563
#
#    freedom_life_choices  generosity  perceptions_of_corruption
# 0               0.66557     0.29678                    0.41978
# 1               0.62877     0.43630                    0.14145
# 2               0.64938     0.34139                    0.48357
# 3               0.66973     0.34699                    0.36503
# 4               0.63297     0.45811                    0.32957

# %% [markdown]
# ## LEARN AND CREATE CAUSAL MODEL STRUCTURE

# %%
from causalnex.structure.notears import from_pandas
sm = from_pandas(struct_data)

# %% [markdown]
# ## PLOT OF CAUSAL GRAPH

# %%
from IPython.display import Image
from causalnex.plots import plot_structure, NODE_STYLE, EDGE_STYLE

# %%
# Generate the network plot
viz = plot_structure(
    sm,
    graph_attributes={"scale": "0.5"},
    all_node_attributes=NODE_STYLE.WEAK,
    all_edge_attributes=EDGE_STYLE.WEAK,
    prog='fdp',
)

# Draw the graph
Image(viz.draw(format='png'))

# %%
sm.remove_edges_below_threshold(0.71)
viz = plot_structure(
    sm,
    graph_attributes={"scale": "0.5"},
    all_node_attributes=NODE_STYLE.WEAK,
    all_edge_attributes=EDGE_STYLE.WEAK,
    prog='fdp',
)

# Draw the graph
Image(viz.draw(format='png'))

# %% [markdown]
# This is a very confusing network graph. Let's:
# - convert column names to english
# - remove low value connections
# - pretty graph up

# %%
# Change column names
struct_data_revised = struct_data.rename(columns = {"gdp_per_capita":"GPD per Capita", 
                              "social_support": "Social Support", 
                              "healthy_life_expectancy":"Healthy Life Expectancy",
                              "freedom_life_choices":"Freedom Life Choices",
                              "generosity":"Generosity",
                              "perceptions_of_corruption":"Perceptions of Corruption"})
struct_data_revised
# Out:
#      score  GPD per Capita  Social Support  Healthy Life Expectancy  \
# 0    7.587         1.39651         1.34951                  0.94143
# 1    7.561         1.30232         1.40223                  0.94784
# 2    7.527         1.32548         1.36058                  0.87464
# 3    7.522         1.45900         1.33095                  0.88521
# 4    7.427         1.32629         1.32261                  0.90563
# ..     ...             ...             ...                      ...
# 620  3.355         0.44200         1.07300                  0.34300
# 621  3.303         0.45500         0.99100                  0.38100
# 622  3.254         0.33700         0.60800                  0.17700
# 623  3.083         0.02400         0.00000                  0.01000
# 624  2.905         0.09100         0.62700                  0.14500
#
#      Freedom Life Choices  Generosity  Perceptions of Corruption
# 0                 0.66557     0.29678                    0.41978
# ...

# %%
from causalnex.structure.notears import from_pandas
sm_refined = from_pandas(struct_data)

# Remove low value relationships
sm_refined.remove_edges_below_threshold(0.71)

# %%
# Make the network pretty :)
node_attributes = {
    node: {
        "fontsize": 10,
        "labelloc": "c",
    }
    for node in sm_refined.nodes
}

edge_attributes = {
    (u, v): {
        "penwidth": w * 1.5,  # Setting edge thickness
        "weight": int(10 * w),  # Higher "weight"s mean shorter edges
        #"arrowsize": 2 - 2.0 * w,  # Avoid too large arrows
        "arrowtail": "dot",
    }
    for u, v, w in sm_refined.edges(data="weight")
}

# Color the target (score) red
for node in sm_refined.nodes:
    if "score" in node:  # We color nodes with "cost" in the name with a orange colour.
        node_attributes[node]["fillcolor"] = "#DF5F00"

# Generate the network plot
viz = plot_structure(sm_refined,
                     prog = "circo",
                     node_attributes=node_attributes,
                     edge_attributes=edge_attributes)

# Draw the graph
Image(viz.draw(
    format="png"
))
# Out:
# /opt/anaconda3/envs/jas_environment/lib/python3.8/site-packages/pygraphviz/agraph.py:1402: RuntimeWarning: Warning: node 'score', graph '' size too small for label
# ...
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
